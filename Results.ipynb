# %%
import pandas as pd

# %%
dat = pd.read_csv('./evalresults.csv')

# %%
dat = dat.drop(columns = 'Unnamed: 0')

# %%
dat.sort_values('profit percentage',ascending = False)
# Out:
#          ticker strategy  ep_count  year     investment        returns  \
# 51         BPCL    t-dqn        10  2019   32867.940666   26562.354737
# 57         BPCL    t-dqn        40  2019   32626.466672   30581.249051
# 61   BHARTIARTL    t-dqn        10  2019   19054.215851   19507.131316
# 63   BHARTIARTL    t-dqn        20  2019   22734.874545   23369.327207
# 41   BAJAJFINSV    t-dqn        10  2019  548643.805667  553426.731939
# 59         BPCL    t-dqn        50  2019   45516.740262   32717.009853
# 69   BHARTIARTL    t-dqn        50  2019   24025.938478   22622.091704
# 48   BAJAJFINSV    t-dqn        50  2018  379065.511231  387540.805177
# 15   ASIANPAINT    t-dqn        30  2019   97585.102903   98124.531373
# 7    ADANIPORTS    t-dqn        40  2019   23967.617189   22790.928590
# 12   ASIANPAINT    t-dqn        20  2018   80520.431886   75034.382445
# 33   BAJAJ-AUTO    t-dqn        20  2019  285921.856936  262860.337159
# ...

# %%
dat[dat['year'] == 2018]['profit percentage'].mean()
# Out:
# 0.5414212471978209

# %%
dat[dat['year'] == 2019]['profit percentage'].mean()
# Out:
# 6.966445834203416
